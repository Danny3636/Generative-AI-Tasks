# %% [markdown]
# <a href="https://colab.research.google.com/github/Danny3636/Generative-AI-Tasks/blob/main/Required_Task_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# From Task 9, I learned the critical lesson that LLMs are unreliable for precise calculations involving dates and 'calendar math.' For such tasks, especially those affected by factors like leap years or irregular payment schedules, using code execution tools is essential to ensure accurate and trustworthy results, rather than relying on an LLM's estimations.

# %% [markdown]
# The Prompt:
#
# "You are a financial auditor. Do not perform the math yourself. Write and execute a Python script to calculate the loan amortization.
#
# Use the datetime library to calculate the exact number of days between the payment dates listed below.
#
# Ensure you account for the 2024 Leap Year (Feb 29).
#
# Formula: Daily_Interest = Balance * (0.12 / 365) * Days_Elapsed.
#
# Inputs: Start Jan 1, 2024 ($100k).
#
# Payments of $5,000 on Jan 31, Feb 29, Mar 31."

# %% [markdown]
# Executive Summary
# Audit Findings: Verified
# The manual audit confirms the bank's calculations are correct. By using a programmatic verification tool, we established that the loan correctly accounted for the 29-day accrual period in February 2024. A standard approximation would have undercharged interest by excluding the leap day. The remaining balance as of March 31, 2024, is $87,838.03.
